# %% [markdown]
# # Graficando curvas

# %%
import matplotlib.pyplot as plt
y = [1,0.5,-0.5,-1,-0.5,0.5,1]
x = [0,1,2,3,4,5,6]

plt.plot(x,y,"r")
plt.title("Gráfico Cosenoidal")
plt.xlabel ("para valores de x avanzando de 60°")
plt.ylabel ("Valores de Y")
plt.legend("f(x)")
plt.savefig("gráfico.png")
plt.show()
